# %% [markdown]
# #서울의 기온 데이터 분석하기

# %% [markdown]
# ##01 데이터 다운로드
#
# *   https://data.kma.go.kr/cmmn/main.do
# *   기온통계분석 - 기온분석 - 기간/지역설정 - CSV 다운로드
# *   기간 : 19071001~20190117

# %% [markdown]
# ###seoul.csv 파일 읽어오기

# %%
import csv

# 1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')
print(data)

# 3) 파일 내용 출력
for row in data:
  print(row)

# 4) 파일 닫기
f.close
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['2005-05-11', '108', '13.7', '12.1', '16.1']
# ['2005-05-12', '108', '14.1', '11.6', '19.6']
# ['2005-05-13', '108', '16.6', '10.1', '23.3']
# ['2005-05-14', '108', '16.7', '13.3', '20.7']
# ['2005-05-15', '108', '18.6', '12.5', '25.7']
# ['2005-05-16', '108', '19.6', '14.3', '25.3']
# ['2005-05-17', '108', '19.4', '16', '23.6']
# ['2005-05-18', '108', '15.4', '11.8', '19.6']
# ['2005-05-19', '108', '17.2', '11.8', '23']
# ['2005-05-20', '108', '18.5', '12.8', '24.5']
# ['2005-05-21', '108', '17.7', '13.6', '22.8']
# ['2005-05-22', '108', '15.9', '14.6', '18.5']
# ['2005-05-23', '108', '16.1', '13.1', '20.1']
# ['2005-05-24', '108', '17.6', '12.3', '23.5']
# ['2005-05-25', '108', '18.5', '12.6', '24']
# ['2005-05-26', '108', '19.3', '15.3', '25']
# ['2005-05-27', '108', '20.7', '14.6', '27.7']
# ['2005-05-28', '108', '22', '15.8', '28.2']
# ['2005-05-29', '108', '23.7', '17.1', '30.2']
# ['2005-05-30', '108', '21.5', '18', '26.7']
# ...

# %% [markdown]
# ### 헤더 저장하기

# %%
import csv

# 1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 4) 파일 닫기
f.close

# 5) 헤더 출력
print(header)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %% [markdown]
# ## 02 최고 기온 출력하기

# %%
import csv

# 1-1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 최고 기온 출력
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[-1] == '':
    row[-1] = -999
  # 날짜와 최고기온 출력
  print(row[0], float(row[-1]))

# 3) 파일 닫기
f.close
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 2005-05-11 16.1
# 2005-05-12 19.6
# 2005-05-13 23.3
# 2005-05-14 20.7
# 2005-05-15 25.7
# 2005-05-16 25.3
# 2005-05-17 23.6
# 2005-05-18 19.6
# 2005-05-19 23.0
# 2005-05-20 24.5
# 2005-05-21 22.8
# 2005-05-22 18.5
# 2005-05-23 20.1
# 2005-05-24 23.5
# 2005-05-25 24.0
# 2005-05-26 25.0
# 2005-05-27 27.7
# 2005-05-28 28.2
# 2005-05-29 30.2
# 2005-05-30 26.7
# 2005-05-31 26.6
# 2005-06-01 24.2
# 2005-06-02 22.2
# 2005-06-03 22.6
# 2005-06-04 23.6
# 2005-06-05 29.1
# 2005-06-06 27.1
# 2005-06-07 25.1
# 2005-06-08 27.7
# 2005-06-09 28.0
# 2005-06-10 23.1
# 2005-06-11 26.8
# 2005-06-12 27.5
# 2005-06-13 31.3
# 2005-06-14 31.8
# 2005-06-15 24.3
# 2005-06-16 25.2
# 2005-06-17 26.3
# 2005-06-18 27.2
# 2005-06-19 29.3
# 2005-06-20 29.5
# 2005-06-21 29.1
# 2005-06-22 29.2
# 2005-06-23 30.8
# 2005-06-24 32.0
# 2005-06-25 29.2
# 2005-06-26 29.1
# 2005-06-27 24.2
# 2005-06-28 28.0
# 2005-06-29 24.3
# 2005-06-30 31.1
# 2005-07-01 26.5
# 2005-07-02 26.1
# ...

# %% [markdown]
# ### 날짜와 평균기온 출력하기

# %%
import csv

# 1-1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 평균 온도 출력
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[2] == '':
    row[2] = -999
  # 날짜와 평균 온도 출력
  print(row[0], float(row[2]))

# 3) 파일 닫기
f.close
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 2005-05-11 13.7
# 2005-05-12 14.1
# 2005-05-13 16.6
# 2005-05-14 16.7
# 2005-05-15 18.6
# 2005-05-16 19.6
# 2005-05-17 19.4
# 2005-05-18 15.4
# 2005-05-19 17.2
# 2005-05-20 18.5
# 2005-05-21 17.7
# 2005-05-22 15.9
# 2005-05-23 16.1
# 2005-05-24 17.6
# 2005-05-25 18.5
# 2005-05-26 19.3
# 2005-05-27 20.7
# 2005-05-28 22.0
# 2005-05-29 23.7
# 2005-05-30 21.5
# 2005-05-31 21.0
# 2005-06-01 19.8
# 2005-06-02 19.1
# 2005-06-03 18.0
# 2005-06-04 19.5
# 2005-06-05 22.8
# 2005-06-06 22.2
# 2005-06-07 21.7
# 2005-06-08 23.0
# 2005-06-09 23.6
# 2005-06-10 19.1
# 2005-06-11 21.0
# 2005-06-12 21.8
# 2005-06-13 24.8
# 2005-06-14 24.1
# 2005-06-15 21.2
# 2005-06-16 21.2
# 2005-06-17 22.5
# 2005-06-18 23.1
# 2005-06-19 23.6
# 2005-06-20 23.6
# 2005-06-21 24.5
# 2005-06-22 24.1
# 2005-06-23 24.4
# 2005-06-24 25.9
# 2005-06-25 25.4
# 2005-06-26 24.7
# 2005-06-27 22.7
# 2005-06-28 23.8
# 2005-06-29 22.8
# 2005-06-30 25.7
# 2005-07-01 23.8
# 2005-07-02 23.9
# ...

# %% [markdown]
# ### 날짜와 최저기온 출력하기

# %%
import csv

# 1-1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 최저 기온 출력
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[-2] == '':
    row[-2] = -999
  # 날짜와 최저 기온 출력
  print(row[0], float(row[-2]))

# 3) 파일 닫기
f.close
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 2005-05-11 12.1
# 2005-05-12 11.6
# 2005-05-13 10.1
# 2005-05-14 13.3
# 2005-05-15 12.5
# 2005-05-16 14.3
# 2005-05-17 16.0
# 2005-05-18 11.8
# 2005-05-19 11.8
# 2005-05-20 12.8
# 2005-05-21 13.6
# 2005-05-22 14.6
# 2005-05-23 13.1
# 2005-05-24 12.3
# 2005-05-25 12.6
# 2005-05-26 15.3
# 2005-05-27 14.6
# 2005-05-28 15.8
# 2005-05-29 17.1
# 2005-05-30 18.0
# 2005-05-31 15.8
# 2005-06-01 15.5
# 2005-06-02 17.6
# 2005-06-03 15.6
# 2005-06-04 15.8
# 2005-06-05 16.0
# 2005-06-06 18.2
# 2005-06-07 18.3
# 2005-06-08 18.3
# 2005-06-09 18.6
# 2005-06-10 18.0
# 2005-06-11 16.6
# 2005-06-12 17.5
# 2005-06-13 18.7
# 2005-06-14 20.3
# 2005-06-15 19.0
# 2005-06-16 17.8
# 2005-06-17 19.7
# 2005-06-18 20.6
# 2005-06-19 19.7
# 2005-06-20 19.0
# 2005-06-21 22.0
# 2005-06-22 21.0
# 2005-06-23 20.7
# 2005-06-24 21.2
# 2005-06-25 22.2
# 2005-06-26 21.1
# 2005-06-27 20.7
# 2005-06-28 20.5
# 2005-06-29 21.7
# 2005-06-30 22.3
# 2005-07-01 21.6
# 2005-07-02 22.8
# ...

# %% [markdown]
# ## 03 기상 관측 이래, 서울의 최고 기온이 가장 높았던 날은 언제였고 몇도 였을까?

# %%
import csv

# 0) 최고 기온이 가장 높았던 날짜와 온도를 저장할 변수 선언
max_date = '' # 최고 기온이 가장 높았던 날짜
max_temp = -999 # 최고 기온이 가장 높았던 온도 -> 초기화를 극적인 값으로 설정

# 1-1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 최고 기온 찾기
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[-1] == '':
    row[-1] = -999

  # 2-2) 최고 기온 형변환
  row[-1] = float(row[-1])

  # 2-3) 저장된 최고 기온과 현재 최고 기온을 비교해서 더 높은 온도의 최고 기온과 날짜를 저장
  if max_temp < row[-1]:
    max_date = row[0]
    max_temp = row[-1]

# 3) 파일 닫기
f.close

# 4) rufrhk cnffur
print('기상 관측 이래, 서울의 최고 기온이 가장 높았던 날은', max_date, '온도는', max_temp, '였습니다.')
# Out:
# 기상 관측 이래, 서울의 최고 기온이 가장 높았던 날은 2018-08-01 온도는 39.6 였습니다.

# %% [markdown]
# ## 04 기상 관측 이래, 서울의 최저 기온이 가장 낮았던 날은 언제였고 몇도 였을까?

# %%
import csv

# 0) 최저 기온이 가장 높았던 날짜와 온도를 저장할 변수 선언
min_date = '' # 최고 기온이 가장 높았던 날짜
min_temp = 999 # 최고 기온이 가장 높았던 온도 -> 초기화를 극적인 값으로 설정

# 1-1) 파일을 연다.
f = open('/content/seoul.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 최저 기온 찾기
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[3] == '':
    row[3] = 999

  # 2-2) 최저 기온 형변환
  row[3] = float(row[3])

  # 2-3) 저장된 최저 기온과 현재 최저 기온을 비교해서 더 낮은 온도의 최저 기온과 날짜를 저장
  if min_temp > row[3]:
    min_date = row[0]
    min_temp = row[3]

# 3) 파일 닫기
f.close

# 4) rufrhk cnffur
print('기상 관측 이래, 서울의 최저 기온이 가장 낮았던 날은', min_date, '온도는', min_temp, '였습니다.')
# Out:
# 기상 관측 이래, 서울의 최저 기온이 가장 낮았던 날은 1927-12-31 온도는 -23.1 였습니다.

# %% [markdown]
# ## 05 기상 관측 이래, 인천의 최고 기온이 가장 높았던 날은 언제였고 몇도였을까?

# %%
import csv

# 0) 최고 기온이 가장 높았던 날짜와 온도를 저장할 변수 선언
max_date = '' # 최고 기온이 가장 높았던 날짜
max_temp = -999 # 최고 기온이 가장 높았던 온도 -> 초기화를 극적인 값으로 설정

# 1-1) 파일을 연다.
f = open('/content/incheon.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 최고 기온 찾기
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[-1] == '':
    row[-1] = -999

  # 2-2) 최고 기온 형변환
  row[-1] = float(row[-1])

  # 2-3) 저장된 최고 기온과 현재 최고 기온을 비교해서 더 높은 온도의 최고 기온과 날짜를 저장
  if max_temp < row[-1]:
    max_date = row[0]
    max_temp = row[-1]

# 3) 파일 닫기
f.close

# 4) rufrhk cnffur
print('기상 관측 이래, 인천의 최고 기온이 가장 높았던 날은', max_date, '온도는', max_temp, '였습니다.')
# Out:
# 기상 관측 이래, 인천의 최고 기온이 가장 높았던 날은 1949-07-16 온도는 38.9 였습니다.

# %%
import csv

# 0) 최저 기온이 가장 높았던 날짜와 온도를 저장할 변수 선언
min_date = '' # 최고 기온이 가장 높았던 날짜
min_temp = 999 # 최고 기온이 가장 높았던 온도 -> 초기화를 극적인 값으로 설정

# 1-1) 파일을 연다.
f = open('/content/incheon.csv', 'r', encoding='euc-kr')

# 1-2) 파일을 읽는다.
data = csv.reader(f, delimiter=',')

# 1-3) 헤더 저장
header = next(data) # next() 한줄 읽고, 커서 한칸 이동

# 2) 날짜, 최저 기온 찾기
for row in data:
  # 2-1) 결측치 데이터 처리 -> 지우거나, 채우거나(명확한 결과를 위해서 극단적인 값으로 초기화 -999)
  if row[3] == '':
    row[3] = 999

  # 2-2) 최저 기온 형변환
  row[3] = float(row[3])

  # 2-3) 저장된 최저 기온과 현재 최저 기온을 비교해서 더 낮은 온도의 최저 기온과 날짜를 저장
  if min_temp > row[3]:
    min_date = row[0]
    min_temp = row[3]

# 3) 파일 닫기
f.close

# 4) rufrhk cnffur
print('기상 관측 이래, 인천의 최저 기온이 가장 낮았던 날은', min_date, '온도는', min_temp, '였습니다.')
# Out:
# 기상 관측 이래, 인천의 최저 기온이 가장 낮았던 날은 1931-01-11 온도는 -21.0 였습니다.

# %% [markdown]
# # matplotib 라이브러리 기본 그래프

# %%
import matplotlib.pyplot as plt

plt.plot([10, 20, 10, 40, 50]) # plot(y) y값이 주어지면, x값은 자동으로 0부터 1씩 증가
plt.show()

# %% [markdown]
# ## 01 기본 그래프 plot(x, y)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('ploating') # 타이틀 속성 추가
plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.show()

# %% [markdown]
# ## 02 여러개를 한번에 그리는 plot(x, y, label=")

# %%
import matplotlib.pyplot as plt

plt.title('ploating') # 타이틀 속성 추가

# 1개 이상의 차트를 같이 그릴 경우 label 속성 추가
plt.plot([1, 2, 3, 4], [10, 20, 30, 40], label='asc')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], label='desc')

#범례 속성 추가
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('ploating') # 타이틀 속성 추가

# 1개 이상의 차트를 같이 그릴 경우 label 속성 추가, 색상 변경
plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='skyblue', marker='.', linestyle='--', label='asc')
#plt.plot([1, 2, 3, 4], [10, 20, 30, 40], c='skyblue', marker='.', ls='--', label='asc')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'r^--', label='desc') #축약형

#범례 속성 추가
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('ploating') # 타이틀 속성 추가

# 1개 이상의 차트를 같이 그릴 경우 label 속성 추가, 색상 변경, 마커, 라인스타일 추가
plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='skyblue', marker='.', linestyle='', label='asc')
#plt.plot([1, 2, 3, 4], [10, 20, 30, 40], c='skyblue', marker='.', ls='--', label='asc')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'g^', label='desc') #축약형

#범례 속성 추가
plt.legend()
plt.show()

# %% [markdown]
# ## 03 서울 기온 데이터 시각화

# %% [markdown]
# ### 최고 기온 시각화

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/seoul.csv', 'r', encoding='euc=kr')

data = csv.reader(f)
header = next(data)

# 결측치를 제외한 데이터만 시각화
result = []

for row in data:
  if row[-1] != '':
    result.append(float(row[-1]))

plt.title('seoul')
plt.plot(result, 'r.')
plt.show()
